# %% [markdown]
# # Asana to Scoro Migration
#
# This notebook runs the complete migration process from Asana to Scoro.
#
# ## Setup Instructions
#
# 1. Ensure you have a `.env` file in the project root with:
#    - `ASANA_ACCESS_TOKEN=your_token`
#    - `SCORO_API_KEY=your_key`
#    - `SCORO_COMPANY_NAME=your_company`
#
# 2. Install dependencies:
#    ```bash
#    pip install -r requirements.txt
#    ```
#
# 3. Run the cells below in order.

# %%
# Import required libraries
import sys
import os
import json
from datetime import datetime

# Add project root to path
sys.path.insert(0, os.path.abspath('.'))

# Import project modules
from clients import AsanaClient, ScoroClient
from models import MigrationSummary
from exporters import export_asana_project
from transformers import transform_data, reset_task_tracker, get_deduplication_stats
from importers import import_to_scoro
from utils import logger

print("✓ All imports successful")
# Out:
# ✓ All imports successful

# %% [markdown]
# ## Configuration
#
# Configure the project you want to migrate. You can use either:
# - **Project GID** (recommended, faster): Direct project identifier
# - **Project Name**: Search by name (slower)
#
# Set the values below:

# %%
# Configuration - Modify these values as needed
PROJECT_GID = "1207816263671761"  # Set to None if using project_name instead
WORKSPACE_GID = "10447183158961"
PROJECT_NAME = None  # Set to project name if not using GID

# Display configuration
print("Migration Configuration:")
print(f"  Project GID: {PROJECT_GID}")
print(f"  Workspace GID: {WORKSPACE_GID}")
print(f"  Project Name: {PROJECT_NAME}")
print(f"  Using: {'Project GID' if PROJECT_GID else 'Project Name'}")
# Out:
# Migration Configuration:
#   Project GID: 1207816263671761
#   Workspace GID: 10447183158961
#   Project Name: None
#   Using: Project GID

# %% [markdown]
# ## Phase 1: Initialize Clients and Test Connections

# %%
# Initialize clients
print("="*60)
print("Initializing API clients...")
print("="*60)

try:
    # Initialize Asana client
    asana_client = AsanaClient()
    print("✓ Asana client initialized")
    
    # Test Asana connection
    print("\nTesting Asana API connection...")
    if asana_client.test_connection():
        print("✓ Asana connection test successful")
    else:
        print("✗ Asana connection test failed")
        print("\nPossible issues:")
        print("  1. Your ASANA_ACCESS_TOKEN may be invalid or expired")
        print("  2. The token may not have the required permissions")
        print("  3. Check that your .env file is in the correct location")
        raise ValueError("Asana connection failed")
        
except ValueError as e:
    print(f"✗ Authentication Error: {e}")
    print("\nPlease ensure your .env file contains a valid ASANA_ACCESS_TOKEN.")
    print("You can create a Personal Access Token at: https://app.asana.com/0/developer-console")
    raise

# Initialize Scoro client
scoro_client = ScoroClient()

# Test Scoro connection
print("\nTesting Scoro connection...")
try:
    scoro_projects = scoro_client.list_projects()
    print(f"✓ Connected to Scoro. Found {len(scoro_projects)} existing projects.")
    if scoro_projects:
        print("  Sample projects:")
        for proj in scoro_projects[:5]:  # Show first 5
            print(f"    - {proj.get('name', 'Unknown')}")
except Exception as e:
    print(f"✗ Error connecting to Scoro: {e}")
    raise

print("\n✓ All clients initialized and tested successfully")
# Out:
# 2025-11-20 09:03:40,982 - INFO - Loading Asana token: 2/12...08c2 (length: 68)
# 2025-11-20 09:03:41,000 - INFO - Asana client initialized
# ============================================================
# Initializing API clients...
# ============================================================
# ✓ Asana client initialized
#
# Testing Asana API connection...
# 2025-11-20 09:03:41,492 - INFO - Connection test successful. Found 1 workspace(s).
# 2025-11-20 09:03:41,494 - INFO - Scoro base URL: https://halsteadmedia8.scoro.com/api/v2/
# 2025-11-20 09:03:41,496 - INFO - Scoro client initialized for halsteadmedia8
# ✓ Asana connection test successful
#
# Testing Scoro connection...
# 2025-11-20 09:03:42,206 - INFO - Retrieved 60 projects from Scoro
# ✓ Connected to Scoro. Found 60 existing projects.
#   Sample projects:
#     - Unknown
#     - Unknown
#     - Unknown
#     - Unknown
#     - Unknown
#
# ✓ All clients initialized and tested successfully

# %% [markdown]
# ## Phase 2: Export from Asana

# %%
# Export project from Asana
print("="*60)
print("PHASE 1: EXPORT FROM ASANA")
print("="*60)

if PROJECT_GID:
    print(f"\nExporting project from Asana using GID: {PROJECT_GID}...")
    asana_data = export_asana_project(asana_client, project_gid=PROJECT_GID, workspace_gid=WORKSPACE_GID)
elif PROJECT_NAME:
    print(f"\nExporting project from Asana: '{PROJECT_NAME}'...")
    asana_data = export_asana_project(asana_client, project_name=PROJECT_NAME, workspace_gid=WORKSPACE_GID)
else:
    raise ValueError("Either PROJECT_GID or PROJECT_NAME must be provided")

if not asana_data:
    error_msg = f"✗ Project (GID: {PROJECT_GID if PROJECT_GID else 'name: ' + PROJECT_NAME}) not found or could not be exported."
    print(error_msg)
    raise ValueError(error_msg)

print(f"✓ Successfully exported project with {len(asana_data.get('tasks', []))} tasks")

# Display project details
if asana_data.get('project'):
    proj = asana_data['project']
    print("\nProject Details Retrieved:")
    print(f"  Name: {proj.get('name', 'N/A')}")
    print(f"  GID: {proj.get('gid', 'N/A')}")
    print(f"  Created: {proj.get('created_at', 'N/A')}")
    print(f"  Modified: {proj.get('modified_at', 'N/A')}")

# Display task count
tasks = asana_data.get('tasks', [])
print(f"\nTotal tasks exported: {len(tasks)}")
# Out:
# 2025-11-20 09:03:42,240 - INFO - Starting export using provided project GID: 1207816263671761
# 2025-11-20 09:03:42,243 - INFO - Step 1/5: Retrieving project details using GID...
# ============================================================
# PHASE 1: EXPORT FROM ASANA
# ============================================================
#
# Exporting project from Asana using GID: 1207816263671761...
# 2025-11-20 09:03:42,703 - INFO - Retrieved details for project: Van Zeeland Nursery & Landscape
# 2025-11-20 09:03:42,705 - INFO - ✓ Retrieved project: Van Zeeland Nursery & Landscape (GID: 1207816263671761)
# 2025-11-20 09:03:42,706 - INFO - Step 2/5: Retrieving project tasks...
# 2025-11-20 09:03:51,373 - INFO - Retrieved 568 tasks for project 1207816263671761
# 2025-11-20 09:03:51,375 - INFO - ✓ Found 568 tasks in project
# 2025-11-20 09:03:51,378 - INFO - Step 3/5: Retrieving project sections...
# 2025-11-20 09:03:51,660 - INFO - Retrieved 11 sections for project 1207816263671761
# 2025-11-20 09:03:51,661 - INFO - ✓ Found 11 sections in project
# 2025-11-20 09:03:51,663 - INFO - Step 4/7: Retrieving project milestones...
# 2025-11-20 09:03:54,255 - INFO - Retrieved 7 milestones for project 1207816263671761
# 2025-11-20 09:03:54,257 - INFO - ✓ Found 7 milestones in project
# 2025-11-20 09:03:54,259 - INFO - Step 5/7: Retrieving detailed task information...
# 2025-11-20 09:03:54,261 - INFO -   [1/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:03:55,981 - INFO -   [2/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:03:57,197 - INFO -   [3/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:03:58,315 - INFO -   [4/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:03:59,408 - INFO -   [5/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:00,677 - INFO -   [6/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:02,146 - INFO -   [7/568] Retrieving details for task: (10/31)  [Van Zeeland] DESIGN 2 Case studies
# 2025-11-20 09:04:03,287 - INFO -   [8/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:04,423 - INFO -   [9/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:05,608 - INFO -   [10/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:07,140 - INFO -   [11/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:08,231 - INFO -   [12/568] Retrieving details for task: (11/6) [Van Zeeland] DESIGN 2 Case studies
# 2025-11-20 09:04:09,494 - INFO -   [13/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:10,704 - INFO -   [14/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:11,887 - INFO -   [15/568] Retrieving details for task: Follow up on "(10/2) [Van Zeeland] COPY edit captions"
# 2025-11-20 09:04:13,171 - INFO -   [16/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:14,218 - INFO -   [17/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:15,369 - INFO -   [18/568] Retrieving details for task: [Designer] Confirm CallRail code is in place and working
# 2025-11-20 09:04:16,472 - INFO -   [19/568] Retrieving details for task: Follow up on "(6/17) [Van Zeeland] COPY edit to landing page"
# 2025-11-20 09:04:17,517 - INFO -   [20/568] Retrieving details for task: Follow up on "(5/23) [Van zeeland] COPY add publication feature to site"
# 2025-11-20 09:04:18,677 - INFO -   [21/568] Retrieving details for task: Follow up on "(5/23) [Van Zeeland] COPY donation request page/form"
# 2025-11-20 09:04:19,874 - INFO -   [22/568] Retrieving details for task: Follow up from this meeting: Van Zeeland | Halstead Monthly Meeting with david@vanzeelandnursery.com,kellie@vanzeelandnursery.com
# 2025-11-20 09:04:21,054 - INFO -   [23/568] Retrieving details for task: Follow up on "(5/8) [Van Zeeland] COPY Landing page"
# 2025-11-20 09:04:25,253 - INFO -   [24/568] Retrieving details for task: Ready "(5/5) [Van Zeeland] DESIGN garden center pmlp "
# 2025-11-20 09:04:26,317 - INFO -   [25/568] Retrieving details for task: Ready "[Van Zeeland] DESIGN update hours"
# 2025-11-20 09:04:27,722 - INFO -   [26/568] Retrieving details for task: Ready "[Van Zeeland] Edit to forms "
# 2025-11-20 09:04:28,821 - INFO -   [27/568] Retrieving details for task: Follow up on "[Van Zeeland] SEO Optimization"
# 2025-11-20 09:04:30,095 - INFO -   [28/568] Retrieving details for task: Follow up on "(4/16) [Van Zeeland] COPY door hanger edit"
# 2025-11-20 09:04:31,240 - INFO -   [29/568] Retrieving details for task: Ready "(4/10? ) [Van Zeeland] DESIGN update hours"
# 2025-11-20 09:04:32,449 - INFO -   [30/568] Retrieving details for task: Ready "[Van Zeeland] DESIGN update copy on process page"
# 2025-11-20 09:04:33,916 - INFO -   [31/568] Retrieving details for task: Follow up on "Feedback Edits "(4/2 🔥) [Van Zeeland] COPY edit to flyer""
# 2025-11-20 09:04:34,966 - INFO -   [32/568] Retrieving details for task: Follow up from this meeting: Van Zeeland | Halstead with david@vanzeelandnursery.com,kellie@vanzeelandnursery.com
# 2025-11-20 09:04:35,972 - INFO -   [33/568] Retrieving details for task: Feedback Edits "(4/2 🔥) [Van Zeeland] COPY edit to flyer"
# 2025-11-20 09:04:37,366 - INFO -   [34/568] Retrieving details for task: Ready "one more! "[Van Zeeland] DESIGN after-launch edits to site""
# 2025-11-20 09:04:38,408 - INFO -   [35/568] Retrieving details for task: Follow up on "(4/2) [Van Zeeland] COPY quick update to process page"
# 2025-11-20 09:04:39,498 - INFO -   [36/568] Retrieving details for task: Follow up on "Follow up on "Follow up on "(3/18?) [Van Zeeland] COPY 2 flyers"""
# 2025-11-20 09:04:40,495 - INFO -   [37/568] Retrieving details for task: Follow up on "Follow up on "(3/18?) [Van Zeeland] COPY 2 flyers""
# 2025-11-20 09:04:41,562 - INFO -   [38/568] Retrieving details for task: Ready  "[Van Zeeland] Website how tos for client"
# 2025-11-20 09:04:42,648 - INFO -   [39/568] Retrieving details for task: one more! "[Van Zeeland] DESIGN after-launch edits to site"
# 2025-11-20 09:04:43,744 - INFO -   [40/568] Retrieving details for task: [Van Zeeland] Writer - Incorporate Edits, insert testimonials, and write new page (Visit Us)to Copy
# 2025-11-20 09:04:44,856 - INFO -   [41/568] Retrieving details for task: [Van Zeeland Editor - Edits first 5 Core Pages
# 2025-11-20 09:04:46,236 - INFO -   [42/568] Retrieving details for task: [Van Zeeland] Edit Landscape D&B 1/2
# 2025-11-20 09:04:47,494 - INFO -   [43/568] Retrieving details for task: [Van Zeeland] Editor - Edit Design & Build Copy 1/2
# 2025-11-20 09:04:48,712 - INFO -   [44/568] Retrieving details for task: [Van Zeeland] Editor - Edit Landscape Design & Build 2/2
# 2025-11-20 09:04:49,747 - INFO -   [45/568] Retrieving details for task: [Van Zeeland] Editor - Edits Nursery & Retail
# 2025-11-20 09:04:51,270 - INFO -   [46/568] Retrieving details for task: Edits to 🔥🔥🔥[Van Zeeland] Brochure copy
# 2025-11-20 09:04:52,350 - INFO -   [47/568] Retrieving details for task: Review [Van Zeeland] Brochure
# 2025-11-20 09:04:53,480 - INFO -   [48/568] Retrieving details for task: [Van Zeeland] Writer Full Site Edit
# 2025-11-20 09:04:54,665 - INFO -   [49/568] Retrieving details for task: Ready "edits "[Van Zeeland] DESIGN Full Site Client Feedback for Design 2/2""
# 2025-11-20 09:04:55,909 - INFO -   [50/568] Retrieving details for task: Ready "[Van Zeeland] emails for forms"
# 2025-11-20 09:04:57,047 - INFO -   [51/568] Retrieving details for task: Edit "[Van Zeeland] Create landing pages for paid media "
# 2025-11-20 09:04:58,230 - INFO -   [52/568] Retrieving details for task: Ready "[Van Zeeland] Take Before Pictures"
# 2025-11-20 09:04:59,349 - INFO -   [53/568] Retrieving details for task: Van Zeeland Service Page Links
# 2025-11-20 09:05:00,565 - INFO -   [54/568] Retrieving details for task: A few quick revisions "Van Zeeland Full Site Build Support"
# 2025-11-20 09:05:01,631 - INFO -   [55/568] Retrieving details for task: Ready "[Van Zeeland] designer updates the homepage with client feedback for internal review"
# 2025-11-20 09:05:02,939 - INFO -   [56/568] Retrieving details for task: one edit!! "final edits "DESIGN EDITS "(1/7)🔥🔥🔥[Van Zeeland] Brochure copy"""
# 2025-11-20 09:05:06,625 - INFO -   [57/568] Retrieving details for task: final edits "DESIGN EDITS "(1/7)🔥🔥🔥[Van Zeeland] Brochure copy""
# 2025-11-20 09:05:07,925 - INFO -   [58/568] Retrieving details for task: DESIGN EDITS "(1/7)🔥🔥🔥[Van Zeeland] Brochure copy"
# 2025-11-20 09:05:09,207 - INFO -   [59/568] Retrieving details for task: [Van Zeeland] Write About Us - 2/2
# 2025-11-20 09:05:10,877 - INFO -   [60/568] Retrieving details for task: [Van Zeeland] Write About Us 1/2
# 2025-11-20 09:05:12,088 - INFO -   [61/568] Retrieving details for task: [Van Zeeland] Write Landscape Design & Build 1/2
# 2025-11-20 09:05:13,710 - INFO -   [62/568] Retrieving details for task: [Van Zeeland] Write Landscape Design & Build 2/2
# 2025-11-20 09:05:14,793 - INFO -   [63/568] Retrieving details for task: [Van Zeeland] Write Nursery & Retail
# 2025-11-20 09:05:15,896 - INFO -   [64/568] Retrieving details for task: Follow up on "11/26 [Van Zeeland] Images from video - Take screenshots from video and save to photos folder"
# 2025-11-20 09:05:17,067 - INFO -   [65/568] Retrieving details for task: Add keywords/locations to Agency Analytics and content plan
# 2025-11-20 09:05:18,410 - INFO -   [66/568] Retrieving details for task: Follow up on "[Van Zeeland] Edits to SEO research"
# 2025-11-20 09:05:19,596 - INFO -   [67/568] Retrieving details for task: Follow up on "Follow up on "ASAP [Van Zeeland] Editor creates sitemap""
# 2025-11-20 09:05:20,769 - INFO -   [68/568] Retrieving details for task: Follow up on "[Van Zeeland] ACCESS - DOMAIN login info (Matej) "
# 2025-11-20 09:05:21,879 - INFO -   [69/568] Retrieving details for task: [Van Zeeland] Meeting
# 2025-11-20 09:05:22,959 - INFO -   [70/568] Retrieving details for task: Follow up on "10/8 [Van Zeeland] sem rush analysis"
# 2025-11-20 09:05:24,163 - INFO -   [71/568] Retrieving details for task: ASAP & QUICKEdit on "DESIGN [Van Zeeland] Edit current page "landing page" on web"
# 2025-11-20 09:05:25,330 - INFO -   [72/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:26,914 - INFO -   [73/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:29,118 - INFO -   [74/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:30,645 - INFO -   [75/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:32,575 - INFO -   [76/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:34,005 - INFO -   [77/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:35,650 - INFO -   [78/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:37,131 - INFO -   [79/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:38,657 - INFO -   [80/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:40,235 - INFO -   [81/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:41,814 - INFO -   [82/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:43,392 - INFO -   [83/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:45,253 - INFO -   [84/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:47,220 - INFO -   [85/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:48,934 - INFO -   [86/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:50,715 - INFO -   [87/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:52,826 - INFO -   [88/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:54,818 - INFO -   [89/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:56,414 - INFO -   [90/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:58,088 - INFO -   [91/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:05:59,800 - INFO -   [92/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:01,773 - INFO -   [93/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:03,888 - INFO -   [94/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:05,768 - INFO -   [95/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:07,789 - INFO -   [96/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:09,685 - INFO -   [97/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:11,220 - INFO -   [98/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:12,750 - INFO -   [99/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:14,615 - INFO -   [100/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:16,552 - INFO -   [101/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:18,395 - INFO -   [102/568] Retrieving details for task: [Van Zeeland] Status Update
# 2025-11-20 09:06:21,102 - INFO -   [103/568] Retrieving details for task:
# 2025-11-20 09:06:22,373 - INFO -   [104/568] Retrieving details for task: Facebook Ads Case Studies
# 2025-11-20 09:06:23,610 - INFO -   [105/568] Retrieving details for task: Follow up on "[Van Zeeland] Monthly check-in for SEO (recurring task)"
# 2025-11-20 09:06:25,294 - INFO -   [106/568] Retrieving details for task: Follow up on "(11/6) [Van Zeeland] DESIGN 2 Case studies"
# 2025-11-20 09:06:26,501 - INFO -   [107/568] Retrieving details for task: Follow up on "[Van Zeeland] SEO Optimization"
# 2025-11-20 09:06:27,703 - INFO -   [108/568] Retrieving details for task: Follow up on "(10/22) [Van Zeeland] 2 Case studies - Copywriter writes about video project"
# 2025-11-20 09:06:28,841 - INFO -   [109/568] Retrieving details for task: Follow up on "[Van Zeeland] Monthly check-in for SEO (recurring task)"
# 2025-11-20 09:06:30,016 - INFO -   [110/568] Retrieving details for task: Follow up on "[Van Zeeland] SEO Optimization"
# 2025-11-20 09:06:31,350 - INFO -   [111/568] Retrieving details for task: Follow up on "[Van Zeeland] Monthly check-in for SEO (recurring task)"
# 2025-11-20 09:06:32,511 - INFO -   [112/568] Retrieving details for task: Follow up on "[Van Zeeland] Monthly check-in for SEO (recurring task)"

# %% [markdown]
# ## Phase 3: Transform Data

# %%
# Initialize migration summary and reset task tracker
summary = MigrationSummary()
reset_task_tracker()
print("Task deduplication tracker reset")

# Transform data
print("\n" + "="*60)
print("PHASE 2: TRANSFORM DATA")
print("="*60)
print("\nTransforming data...")

transformed_data = transform_data(asana_data, summary)

# %% [markdown]
# ## Phase 4: Import to Scoro
#
# **Note**: This will create actual projects and tasks in Scoro. Make sure you're ready to proceed.

# %%
# Import to Scoro
print("="*60)
print("PHASE 3: IMPORT TO SCORO")
print("="*60)
print("\n" + "-"*60)
print("NOTE: Import to Scoro is currently enabled.")
print("-"*60)

print("\nImporting to Scoro...")
import_results = import_to_scoro(scoro_client, transformed_data, summary)
print("✓ Import completed")

# %% [markdown]
# ## Phase 5: Results and Summary

# %%
# Print migration summary
print("="*60)
print("MIGRATION SUMMARY")
print("="*60)
summary.print_summary()

# Print deduplication statistics
dedup_stats = get_deduplication_stats()
if dedup_stats['total_tasks_seen'] > 0:
    print("="*60)
    print("DEDUPLICATION STATISTICS")
    print("="*60)
    print(f"Total unique tasks seen: {dedup_stats['total_tasks_seen']}")
    print(f"  - From client projects: {dedup_stats['client_project_tasks']}")
    print(f"  - From team member projects: {dedup_stats['team_member_project_tasks']}")
    print(f"Deduplication: {dedup_stats['total_tasks_seen']} unique tasks "
          f"({dedup_stats['client_project_tasks']} client, "
          f"{dedup_stats['team_member_project_tasks']} team member)")
    print("="*60)

# %% [markdown]
# ## Save Export Data
#
# The exported data is saved to a JSON file for inspection.

# %%
# Save export data to file for inspection
print("Saving exported data to file...")
output_file = f"asana_export_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(asana_data, f, indent=2, default=str)
print(f"✓ Exported data saved to: {output_file}")

print("\n" + "="*60)
print("Migration process completed")
print("="*60)

# %% [markdown]
# ## Optional: View Exported Data
#
# You can inspect the exported data structure below:

# %%
# Display a sample of the exported data
import json

print("Sample of exported Asana data:")
print(json.dumps({
    'project': asana_data.get('project', {}),
    'task_count': len(asana_data.get('tasks', [])),
    'sample_task': asana_data.get('tasks', [{}])[0] if asana_data.get('tasks') else None
}, indent=2, default=str))

# %% [markdown]
# ## Optional: View Transformed Data
#
# You can inspect the transformed data structure below:

# %%
# Display a sample of the transformed data
if transformed_data:
    print("Sample of transformed data:")
    print(json.dumps({
        'projects_count': len(transformed_data.get('projects', [])),
        'tasks_count': len(transformed_data.get('tasks', [])),
        'sample_project': transformed_data.get('projects', [{}])[0] if transformed_data.get('projects') else None,
        'sample_task': transformed_data.get('tasks', [{}])[0] if transformed_data.get('tasks') else None
    }, indent=2, default=str))
